# %% [markdown]
# ## Scott Breitbach
# ### DSC 650, Week 7
# ### 01-May-2022

# %%
# Load libraries
import os
import json
from pathlib import Path
import gzip
import hashlib
import shutil
import pandas as pd
import pygeohash
import s3fs
import uuid
import math
import hashlib

# %%
# Set directories
current_dir = Path(os.getcwd()).absolute()
results_dir = current_dir.joinpath('results')
if results_dir.exists():
    shutil.rmtree(results_dir)
results_dir.mkdir(parents=True, exist_ok=True)
src_data_path = '/home/jovyan/dsc650/data/processed/openflights/routes.jsonl.gz'

# %%
def read_jsonl_data():
    with gzip.open(src_data_path, 'rb') as f:
        records = [json.loads(line) for line in f.readlines()]       
    return records

# %%
def flatten_record(record):
    flat_record = dict()
    for key, value in record.items():
        if key in ['airline', 'src_airport', 'dst_airport']:
            if isinstance(value, dict):
                for child_key, child_value in value.items():
                    flat_key = '{}_{}'.format(key, child_key)
                    flat_record[flat_key] = child_value
        else:
            flat_record[key] = value
    
    return flat_record

# %%
def create_flattened_dataset():
    records = read_jsonl_data()
    parquet_path = results_dir.joinpath('routes-flattened.parquet')
    return pd.DataFrame.from_records([flatten_record(record) for record in records])

# %% [markdown]
# ## Assignment 7.1
# In this part of the assignment, you will partition a dataset using different strategies. You will use the `routes.parquet` dataset you created in a previous assignment. For this dataset, the key for each route will be the three-letter source airport code concatenated with the three-letter destination airport code and the two-letter airline. For instance, a route from Omaha Eppley Airfield (OMA) to Denver International Airport (DEN) on American Airlines (AA) has a key of `OMADENAA`.

# %% [markdown]
# ### a.
# Start by loading the dataset from the previous assignment using Pandas's [`read_parquet()`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.read_parquet.html) method. Next, add the concatenated key then using Panda's [`apply()`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.apply.html) method to create a new column called `key`.

# %%
# Load dataframe
df = create_flattened_dataset()
# Assign keys
df['key'] = df['src_airport_iata'].astype(str) + df['dst_airport_iata'].astype(str) + df['airline_iata'].astype(str)

# %% [markdown]
# For this part of the example, we will create 16 partitions so that we can compare it to the partitions we create from hashed keys in the next part of the assignment. The partitions are determined by the first letter of the composite key using the following partitions.

# %%
partitions = (
    ('A', 'A'), ('B', 'B'), ('C', 'D'), ('E', 'F'),
    ('G', 'H'), ('I', 'J'), ('K', 'L'), ('M', 'M'),
    ('N', 'N'), ('O', 'P'), ('Q', 'R'), ('S', 'T'),
    ('U', 'U'), ('V', 'V'), ('W', 'X'), ('Y', 'Z')
)

# %% [markdown]
# In this case `('A', 'A')` means the folder should contain all of the routes whose composite key starts with `A`. Similarly, `('E', 'F')` should contain routes whose composite key starts with `E` or `F`.
#
# The `results/kv` directory should contain the following folders.

# %%
# kv
# ├── kv_key=A
# ├── kv_key=B
# ├── kv_key=C-D
# ├── kv_key=E-F
# ├── kv_key=G-H
# ├── kv_key=I-J
# ├── kv_key=K-L
# ├── kv_key=M
# ├── kv_key=N
# ├── kv_key=O-P
# ├── kv_key=Q-R
# ├── kv_key=S-T
# ├── kv_key=U
# ├── kv_key=V
# ├── kv_key=W-X
# └── kv_key=Y-Z

# %% [markdown]
# An easy way to create this directory structure is to create a new key called `kv_key` from the `key` column and use the [`to_parquet()`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.to_parquet.html) method with `partition_cols=['kv_key']` to save a partitioned dataset.

# %%
# Set up dictionary of partitions and kv_keys
partition_dict = {}
for i in partitions:
    if i[0] == i[1]:
        partition_dict[i] = i[0]
    else:
        partition_dict[i] = i[0] + '-' + i[1]

# %%
# Generate kv_key from key
def kv_key_gen(data_key):
    for key, val in partition_dict.items():
        if data_key[0] == key[0] or data_key[0] == key[1]:
            return val
    return ''

# %%
# Add kv_key column to df
df['kv_key'] = df['key'].apply(kv_key_gen)

# %%
df[['key', 'kv_key']]
# Out:
#             key kv_key
# 0      AERKZN2B      A
# 1      ASFKZN2B      A
# 2      ASFMRV2B      A
# 3      CEKKZN2B    C-D
# 4      CEKOVB2B    C-D
# ...         ...    ...
# 67658  WYAADLZL    W-X
# 67659  DMEFRUZM    C-D
# 67660  FRUDMEZM    E-F
# 67661  FRUOSSZM    E-F
# 67662  OSSFRUZM    O-P
#
# [67663 rows x 2 columns]

# %%
# Partition dataset using kv_keys
df.to_parquet(results_dir.joinpath('kv'), partition_cols=['kv_key'])

# %% [markdown]
# ### b.
# Next, we are going to partition the dataset again, but this time we will partition by the hash value of the key. The following is a function that will create a SHA256 hash of the input key and return a hexadecimal string representation of the hash.

# %%
import hashlib

def hash_key(key):
    m = hashlib.sha256()
    m.update(str(key).encode('utf-8'))
    return m.hexdigest()

# %% [markdown]
# We will partition the data using the first character of the hexadecimal hash. As such, there are 16 possible partitions. Create a new column called `hashed` that is a hashed value of the `key` column. Next, create a partitioned dataset based on the first character of the hashed key and save the results to `results/hash`. The directory should contain the following folders.

# %%
# hash
# ├── hash_key=0
# ├── hash_key=1
# ├── hash_key=2
# ├── hash_key=3
# ├── hash_key=4
# ├── hash_key=5
# ├── hash_key=6
# ├── hash_key=7
# ├── hash_key=8
# ├── hash_key=9
# ├── hash_key=A
# ├── hash_key=B
# ├── hash_key=C
# ├── hash_key=D
# ├── hash_key=E

# %%
# Add hash column to df
df['hashed'] = df['key'].apply(hash_key)

# %%
# Add hash key column to df for partitioning
df['hash_key'] = df['hashed'].str[0]

# %%
# Partition dataset using hk_hash
df.to_parquet(results_dir.joinpath('hash'), partition_cols=['hash_key'])

# %% [markdown]
# ### c.
# Finally, we will simulate multiple geographically distributed data centers. For this example, we will assume we have three data centers located in the western, central, and eastern United States. Google lists the [locations of their data centers](https://www.google.com/about/datacenters/locations/) and we will use the following locations for our three data centers.
# **West**
# * The Dalles, Oregon
# * Latitude: 45.5945645
# * Longitude: -121.1786823
#
# **Central**
# * Papillion, NE
# * Latitude: 41.1544433
# * Longitude: -96.0422378
#
# **East**
# * Loudoun County, Virginia
# * Latitude: 39.08344
# * Longitude: -77.6497145
#
# Assume that you have an application that provides routes for each of the source airports and you want to store routes in the data center closest to the source airport. The output folders should look as follows.

# %%
# geo
# ├── location=central
# ├── location=east
# └── location=west

# %%
# Get geohash location info for data centers
data_centers = dict(
    west = pygeohash.encode(45.5945645, -121.1786823),
    central = pygeohash.encode(41.1544433, -96.0422378),
    east = pygeohash.encode(39.08344, -77.6497145)
)

# %%
# Get geohash location info for airports
fn = lambda row: pygeohash.encode(row.src_airport_latitude, 
                                  row.src_airport_longitude)
# Add geohash to dataframe
df['geohash'] = df.apply(fn, axis=1)

# %%
def find_closest_datacenter(airport_geohash):
    distance = 20000000
    closest = ''
    for key, val in data_centers.items():
        if pygeohash.geohash_haversine_distance(val, airport_geohash) < distance:
            closest = key
            distance = pygeohash.geohash_haversine_distance(val, airport_geohash)

    return closest

# %%
# Add column for closest data center
df['location'] = df['geohash'].apply(find_closest_datacenter)
# Out:
# The history saving thread hit an unexpected error (OperationalError('database is locked')).History will not be written to the database.

# %%
# Partition dataset using closest data center location
df.to_parquet(results_dir.joinpath('geo'), partition_cols=['location'])

# %% [markdown]
# ### d.
# Create a Python function that takes as input a list of keys and the number of partitions and returns a list of keys sorted into the specified number of partitions. The partitions should be roughly equal in size. Furthermore, the partitions should have the property that each partition contains all the keys between the least key in the partition and the greatest key in the partition. In other words, the partitions should be ordered.

# %%
# Create a list for testing purposes
some_keys = ['S', 'C', 'O', 'T', 'T',
             'M', 'I', 'C', 'H', 'A', 'E', 'L', 
             'B', 'R', 'E', 'I', 'T', 'B', 'A', 'C', 'H']

# %%
def sharded(keys, num_partitions):
    for x in range(0, len(keys), num_partitions):
        chunk = keys[x:num_partitions+x]
        yield(chunk)
        
def balance_partitions(keys, num_partitions):
    keys.sort()
    num_per_group = math.ceil(len(keys) / num_partitions)
    return list(sharded(keys, num_per_group))

# %%
balance_partitions(some_keys, 3)
# Out:
# [['A', 'A', 'B', 'B', 'C', 'C', 'C'],
#  ['E', 'E', 'H', 'H', 'I', 'I', 'L'],
#  ['M', 'O', 'R', 'S', 'T', 'T', 'T']]

# %% [markdown]
# Looks good, but let's try it with uneven groups:

# %%
# Create a list for testing purposes
some_keys = ['S', 'C', 'O', 'T', 'T', 'Y',
             'M', 'I', 'C', 'H', 'A', 'E', 'L', 
             'B', 'R', 'E', 'I', 'T', 'B', 'A', 'C', 'H']

# %%
balance_partitions(some_keys, 3)
# Out:
# [['A', 'A', 'B', 'B', 'C', 'C', 'C', 'E'],
#  ['E', 'H', 'H', 'I', 'I', 'L', 'M', 'O'],
#  ['R', 'S', 'T', 'T', 'T', 'Y']]

# %% [markdown]
# Last group is uneven due to rounding. Let's try to fix that:

# %%
def sharded(keys, n):
    # Get the total number of keys
    num_keys = len(keys)
    # Number of partitions left to make
    num_part_left = n   
    # Set indices for start and end of partition chunk
    chunk_start, chunk_end = 0, math.ceil(num_keys/num_part_left)
    # Number of keys left to partition
    num_keys_left = num_keys - chunk_start
    for x in range(0, n):
        # Create partition chunk
        chunk = keys[chunk_start:chunk_end]
        # Reduce remaining partitions by 1
        num_part_left -= 1
        # Set start index to previous end index
        chunk_start = chunk_end
        # Number of keys left to partition
        num_keys_left = num_keys - chunk_end
        # Calculate end index for next chunk
        if num_part_left > 0: # Note: cannot divide by zero
            chunk_end = chunk_start + math.ceil(num_keys_left/(num_part_left))
        else:
            chunk_end = chunk_start + num_keys_left
        yield(chunk)

# %%
def balance_partitions(keys, num_partitions):
    # Sort list of keys
    keys.sort()
    # Return list of partitions
    return list(sharded(keys, num_partitions))

# %%
balance_partitions(some_keys, 3)
# Out:
# [['A', 'A', 'B', 'B', 'C', 'C', 'C', 'E'],
#  ['E', 'H', 'H', 'I', 'I', 'L', 'M'],
#  ['O', 'R', 'S', 'T', 'T', 'T', 'Y']]

# %% [markdown]
# That looks better, now let's make it work with a column from the dataframe:

# %%
def balance_partitions(keys, num_partitions):
    # Sort list of keys
    try: # sort df column input
        sorted_keys = keys.sort_values()
    except: # sort list input
        sorted_keys = keys
        sorted_keys.sort()
    # Return list of partitions
    return list(sharded(sorted_keys, num_partitions))

# %%
balance_partitions(some_keys, 3)
# Out:
# [['A', 'A', 'B', 'B', 'C', 'C', 'C', 'E'],
#  ['E', 'H', 'H', 'I', 'I', 'L', 'M'],
#  ['O', 'R', 'S', 'T', 'T', 'T', 'Y']]

# %%
balance_partitions(df['airline_country'], 1000)
# Out:
# [11836    ALASKA
#  11879    ALASKA
#  11878    ALASKA
#  11877    ALASKA
#  11876    ALASKA
#            ...
#  11882    ALASKA
#  11913    ALASKA
#  11849    ALASKA
#  11847    ALASKA
#  11812    ALASKA
#  Name: airline_country, Length: 68, dtype: object,
#  11811    ALASKA
#  11810    ALASKA
#  11809    ALASKA
#  11808    ALASKA
#  11807    ALASKA
#            ...
#  11915    ALASKA
#  11916    ALASKA
#  12013    ALASKA
#  12012    ALASKA
#  12011    ALASKA
#  Name: airline_country, Length: 68, dtype: object,
#  12010    ALASKA
#  12009    ALASKA
#  12008    ALASKA
#  12007    ALASKA
#  12006    ALASKA
#            ...
#  11945    ALASKA
#  11944    ALASKA
#  11943    ALASKA
#  11942    ALASKA
#  11941    ALASKA
#  Name: airline_country, Length: 68, dtype: object,
#  11940    ALASKA
#  11939    ALASKA
#  11938    ALASKA
#  11937    ALASKA
#  11936    ALASKA
#            ...
#  11612    ALASKA
#  11611    ALASKA
#  11610    ALASKA
#  11609    ALASKA
#  11608    ALASKA
#  Name: airline_country, Length: 68, dtype: object,
#  11607    ALASKA
#  11606    ALASKA
#  11605    ALASKA
#  11604    ALASKA
#  11603    ALASKA
#            ...
#  11544    ALASKA
#  11543    ALASKA
#  11542    ALASKA
#  11541    ALASKA
#  11540    ALASKA
#  Name: airline_country, Length: 68, dtype: object,
#  11539    ALASKA
#  11538    ALASKA
#  11537    ALASKA
#  11536    ALASKA
#  11535    ALASKA
#            ...
#  11741    ALASKA
#  11740    ALASKA
#  11739    ALASKA
#  11738    ALASKA
#  11737    ALASKA
#  Name: airline_country, Length: 68, dtype: object,
#  11736    ALASKA
#  11735    ALASKA
#  11734    ALASKA
#  11733    ALASKA
#  11732    ALASKA
#            ...
#  11672    ALASKA
#  11671    ALASKA
#  11670    ALASKA
#  11669    ALASKA
#  11668    ALASKA
#  Name: airline_country, Length: 68, dtype: object,
#  11667     ALASKA
#  11666     ALASKA
#  11665     ALASKA
#  11664     ALASKA
#  11663     ALASKA
#            ...
#  12331    AVIANCA
#  12333    AVIANCA
#  12334    AVIANCA
#  12335    AVIANCA
#  12336    AVIANCA
#  Name: airline_country, Length: 68, dtype: object,
#  12337    AVIANCA
#  12338    AVIANCA
#  12322    AVIANCA
#  12321    AVIANCA
#  12320    AVIANCA
#            ...
#  12379    AVIANCA
#  12301    AVIANCA
#  12299    AVIANCA
#  12554    AVIANCA
#  12553    AVIANCA
#  Name: airline_country, Length: 68, dtype: object,
#  12552    AVIANCA
#  12551    AVIANCA
#  12550    AVIANCA
#  12549    AVIANCA
#  12548    AVIANCA
#            ...
#  12529    AVIANCA
#  12518    AVIANCA
#  12528    AVIANCA
#  12526    AVIANCA
#  12525    AVIANCA
#  Name: airline_country, Length: 68, dtype: object,
#  12524    AVIANCA
#  12523    AVIANCA
#  12522    AVIANCA
#  12521    AVIANCA
#  12520    AVIANCA
#            ...
#  12497    AVIANCA
#  12498    AVIANCA
#  12499    AVIANCA
#  12500    AVIANCA
#  12501    AVIANCA
#  Name: airline_country, Length: 68, dtype: object,
#  12381    AVIANCA
#  12473    AVIANCA
#  12445    AVIANCA
#  12458    AVIANCA
#  12443    AVIANCA
#            ...
#  12440    AVIANCA
#  12441    AVIANCA
#  12442    AVIANCA
#  12420    AVIANCA
#  12419    AVIANCA
#  Name: airline_country, Length: 68, dtype: object,
#  1202     Afghanistan
#  48136    Afghanistan
#  1203     Afghanistan
#  1204     Afghanistan
#  1205     Afghanistan
#              ...
#  10219        Algeria
#  10218        Algeria
#  10217        Algeria
#  10216        Algeria
#  10215        Algeria
#  Name: airline_country, Length: 68, dtype: object,
#  10214    Algeria
#  10083    Algeria
#  10069    Algeria
#  10071    Algeria
#  10072    Algeria
#            ...
#  10177    Algeria
#  10176    Algeria
#  10175    Algeria
#  10174    Algeria
#  10173    Algeria
#  Name: airline_country, Length: 68, dtype: object,
#  10172    Algeria
#  10171    Algeria
#  10170    Algeria
#  10169    Algeria
#  10167    Algeria
#            ...
#  10107    Algeria
#  10106    Algeria
#  10105    Algeria
#  10104    Algeria
#  10103    Algeria
#  Name: airline_country, Length: 68, dtype: object,
#  10102    Algeria
#  10101    Algeria
#  10100    Algeria
#  10099    Algeria
#  10098    Algeria
#            ...
#  10054    Algeria
#  10055    Algeria
#  10056    Algeria
#  10057    Algeria
#  10058    Algeria
#  Name: airline_country, Length: 68, dtype: object,
#  10059    Algeria
#  10060    Algeria
#  10061    Algeria
#  10062    Algeria
#  10063    Algeria
#            ...
#  22045     Angola
#  22046     Angola
#  22035     Angola
#  22047     Angola
#  22049     Angola
#  Name: airline_country, Length: 68, dtype: object,
#  22050                 Angola
#  22051                 Angola
#  22052                 Angola
#  22053                 Angola
#  22054                 Angola
#                  ...
#  38905    Antigua and Barbuda
#  38904    Antigua and Barbuda
#  38910    Antigua and Barbuda
#  38918    Antigua and Barbuda
#  38935    Antigua and Barbuda
#  Name: airline_country, Length: 68, dtype: object,
#  38920    Antigua and Barbuda
#  38945    Antigua and Barbuda
#  38944    Antigua and Barbuda
#  38943    Antigua and Barbuda
#  38942    Antigua and Barbuda
#                  ...
#  40919              Argentina
#  28293              Argentina
#  40920              Argentina
#  40922              Argentina
#  40923              Argentina
#  Name: airline_country, Length: 68, dtype: object,
#  40924    Argentina
#  40925    Argentina
#  40926    Argentina
#  40927    Argentina
#  40928    Argentina
#             ...
#  11455    Argentina
#  11456    Argentina
#  11457    Argentina
#  11458    Argentina
#  11452    Argentina
#  Name: airline_country, Length: 68, dtype: object,
#  11478    Argentina
#  11479    Argentina
#  11480    Argentina
#  11500    Argentina
#  11501    Argentina
#             ...
#  4477     Argentina
#  4476     Argentina
#  4475     Argentina
#  4474     Argentina
#  11387    Argentina
#  Name: airline_country, Length: 68, dtype: object,
#  11386    Argentina
#  11385    Argentina
#  11384    Argentina
#  1066     Argentina
#  1065     Argentina
#             ...
#  40948    Argentina
#  11413    Argentina
#  11415    Argentina
#  11411    Argentina
#  4469     Argentina
#  Name: airline_country, Length: 68, dtype: object,
#  4468     Argentina
#  4467     Argentina
#  4466     Argentina
#  4465     Argentina
#  4464     Argentina
#             ...
#  46987    Australia
#  46984    Australia
#  46980    Australia
#  46982    Australia
#  46981    Australia
#  Name: airline_country, Length: 68, dtype: object,
#  46993    Australia
#  46979    Australia
#  46978    Australia
#  46977    Australia
#  46976    Australia
#             ...
#  47118    Australia
#  47117    Australia
#  47116    Australia
#  47115    Australia
#  47114    Australia
#  Name: airline_country, Length: 68, dtype: object,
#  47113    Australia
#  47112    Australia
#  47111    Australia
#  47110    Australia
#  47109    Australia
#             ...
#  46967    Australia
#  61221    Australia
#  61223    Australia
#  61224    Australia
#  61225    Australia
#  Name: airline_country, Length: 68, dtype: object,
#  61226    Australia
#  61227    Australia
#  61228    Australia
#  61229    Australia
#  61230    Australia
#             ...
#  47066    Australia
#  47051    Australia
#  47049    Australia
#  47048    Australia
#  47047    Australia
#  Name: airline_country, Length: 68, dtype: object,
#  47046    Australia
#  47045    Australia
#  47044    Australia
#  47043    Australia
#  47042    Australia
#             ...
#  35018    Australia
#  35019    Australia
#  35020    Australia
#  35021    Australia
#  35022    Australia
#  Name: airline_country, Length: 68, dtype: object,
#  35023    Australia
#  35024    Australia
#  35025    Australia
#  35015    Australia
#  35002    Australia
#             ...
#  35032    Australia
#  35033    Australia
#  35034    Australia
#  35035    Australia
#  35036    Australia
#  Name: airline_country, Length: 68, dtype: object,
#  35037    Australia
#  35038    Australia
#  35039    Australia
#  35040    Australia
#  35041    Australia
#             ...
#  25794    Australia
#  25795    Australia
#  25796    Australia
#  25774    Australia
#  25773    Australia
#  Name: airline_country, Length: 68, dtype: object,
#  25772    Australia
#  34919    Australia
#  34920    Australia
#  34921    Australia
#  34922    Australia
#             ...
#  46891    Australia
#  46892    Australia
#  46893    Australia
#  46894    Australia
#  46895    Australia
#  Name: airline_country, Length: 68, dtype: object,
#  46896    Australia
#  46886    Australia
#  46897    Australia
#  46899    Australia
#  46900    Australia
#             ...
#  46959    Australia
#  46960    Australia
#  46961    Australia
#  46962    Australia
#  46939    Australia
#  Name: airline_country, Length: 68, dtype: object,
#  46859    Australia
#  46938    Australia
#  46936    Australia
#  46913    Australia
#  46914    Australia
#             ...
#  46761    Australia
#  46762    Australia
#  46763    Australia
#  46764    Australia
#  46765    Australia
#  Name: airline_country, Length: 68, dtype: object,
#  46766    Australia
#  46767    Australia
#  46768    Australia
#  46769    Australia
#  46770    Australia
#             ...
#  46828    Australia
#  46829    Australia
#  46831    Australia
#  61175    Australia
#  25775    Australia
#  Name: airline_country, Length: 68, dtype: object,
#  61173    Australia
#  60953    Australia
#  60954    Australia
#  60955    Australia
#  60956    Australia
#             ...
#  67616    Australia
#  67617    Australia
#  67618    Australia
#  67619    Australia
#  67620    Australia
#  Name: airline_country, Length: 68, dtype: object,
#  67621    Australia
#  67622    Australia
#  67623    Australia
#  67624    Australia
#  61003    Australia
#             ...
#  49563    Australia
#  49564    Australia
#  67609    Australia
#  67608    Australia
#  67607    Australia
#  Name: airline_country, Length: 68, dtype: object,
#  67606    Australia
#  67605    Australia
#  67604    Australia
#  67603    Australia
#  67602    Australia
#             ...
#  60999    Australia
#  67628    Australia
#  67627    Australia
#  61103    Australia
#  61104    Australia
#  Name: airline_country, Length: 68, dtype: object,
#  61105    Australia
#  61106    Australia
#  61107    Australia
#  61108    Australia
#  61109    Australia
#             ...
#  61167    Australia
#  61168    Australia
#  61169    Australia
#  61170    Australia
#  61171    Australia
#  Name: airline_country, Length: 68, dtype: object,
#  61172    Australia
#  61151    Australia
#  61150    Australia
#  61149    Australia
#  61148    Australia
#             ...
#  67637    Australia
#  67638    Australia
#  67639    Australia
#  67640    Australia
#  67641    Australia
#  Name: airline_country, Length: 68, dtype: object,
#  67642    Australia
#  67643    Australia
#  67644    Australia
#  67645    Australia
#  67646    Australia
#             ...
#  44744      Austria
#  44743      Austria
#  44749      Austria
#  44750      Austria
#  44752      Austria
#  Name: airline_country, Length: 68, dtype: object,
#  44754    Austria
#  44748    Austria
#  44753    Austria
#  44739    Austria
#  44741    Austria
#            ...
#  44600    Austria
#  44599    Austria
#  44598    Austria
#  44597    Austria
#  44596    Austria
#  Name: airline_country, Length: 68, dtype: object,
#  44595    Austria
#  51749    Austria
#  44593    Austria
#  44592    Austria
#  44611    Austria
#            ...
#  44578    Austria
#  44577    Austria
#  44576    Austria
#  44575    Austria
#  44574    Austria
#  Name: airline_country, Length: 68, dtype: object,
#  44573    Austria
#  44572    Austria
#  44571    Austria
#  44570    Austria
#  44569    Austria
#            ...
#  44648    Austria
#  44647    Austria
#  44646    Austria
#  44645    Austria
#  44644    Austria
#  Name: airline_country, Length: 68, dtype: object,
#  44643    Austria
#  44642    Austria
#  44641    Austria
#  44640    Austria
#  44639    Austria
#            ...
#  30828    Austria
#  30845    Austria
#  30846    Austria
#  30847    Austria
#  419      Austria
#  Name: airline_country, Length: 68, dtype: object,
#  420      Austria
#  421      Austria
#  422      Austria
#  423      Austria
#  424      Austria
#            ...
#  30744    Austria
#  30758    Austria
#  30775    Austria
#  30776    Austria
#  30777    Austria
#  Name: airline_country, Length: 68, dtype: object,
#  30809    Austria
#  30808    Austria
#  30807    Austria
#  30806    Austria
#  30805    Austria
#            ...
#  51738    Austria
#  51737    Austria
#  51736    Austria
#  51735    Austria
#  51733    Austria
#  Name: airline_country, Length: 68, dtype: object,
#  51732    Austria
#  51731    Austria
#  51730    Austria
#  51729    Austria
#  51728    Austria
#            ...
#  58456    Bahamas
#  58455    Bahamas
#  58454    Bahamas
#  58453    Bahamas
#  58452    Bahamas
#  Name: airline_country, Length: 68, dtype: object,
#  58451    Bahamas
#  58458    Bahamas
#  58450    Bahamas
#  58449    Bahamas
#  58448    Bahamas
#            ...
#  46649    Bahamas
#  46654    Bahamas
#  46653    Bahamas
#  29933    Bahrain
#  29932    Bahrain
#  Name: airline_country, Length: 68, dtype: object,
#  29931    Bahrain
#  29930    Bahrain
#  29929    Bahrain
#  29923    Bahrain
#  29903    Bahrain
#            ...
#  29891    Bahrain
#  29924    Bahrain
#  29917    Bahrain
#  29918    Bahrain
#  29919    Bahrain
#  Name: airline_country, Length: 68, dtype: object,
#  29920       Bahrain
#  29921       Bahrain
#  29922       Bahrain
#  29925       Bahrain
#  29926       Bahrain
#              ...
#  14372    Bangladesh
#  14373    Bangladesh
#  14366    Bangladesh
#  14374    Bangladesh
#  14376    Bangladesh
#  Name: airline_country, Length: 68, dtype: object,
#  14377    Bangladesh
#  14378    Bangladesh
#  14379    Bangladesh
#  14380    Bangladesh
#  14381    Bangladesh
#              ...
#  13795       Belarus
#  13794       Belarus
#  13793       Belarus
#  13791       Belarus
#  13790       Belarus
#  Name: airline_country, Length: 68, dtype: object,
#  13789    Belarus
#  13788    Belarus
#  13787    Belarus
#  13792    Belarus
#  13811    Belarus
#            ...
#  13838    Belarus
#  13839    Belarus
#  13840    Belarus
#  13849    Belarus
#  13841    Belarus
#  Name: airline_country, Length: 68, dtype: object,
#  13842    Belarus
#  13843    Belarus
#  13844    Belarus
#  13845    Belarus
#  13846    Belarus
#            ...
#  50248    Belgium
#  50249    Belgium
#  50250    Belgium
#  50238    Belgium
#  50197    Belgium
#  Name: airline_country, Length: 68, dtype: object,
#  50293    Belgium
#  50291    Belgium
#  50360    Belgium
#  50361    Belgium
#  50362    Belgium
#            ...
#  50209    Belgium
#  50210    Belgium
#  54279    Belgium
#  54278    Belgium
#  54277    Belgium
#  Name: airline_country, Length: 68, dtype: object,
#  54276    Belgium
#  54275    Belgium
#  54274    Belgium
#  50211    Belgium
#  50212    Belgium
#            ...
#  50342    Belgium
#  50343    Belgium
#  50344    Belgium
#  50205    Belgium
#  50204    Belgium
#  Name: airline_country, Length: 68, dtype: object,
#  50203    Belgium
#  50222    Belgium
#  50223    Belgium
#  50224    Belgium
#  50225    Belgium
#            ...
#  42609     Belize
#  42608     Belize
#  42607     Belize
#  42606     Belize
#  42603     Belize
#  Name: airline_country, Length: 68, dtype: object,
#  42602                    Belize
#  42605                    Belize
#  46003                    Belize
#  42616                    Belize
#  4633                      Benin
#                    ...
#  66342                   Bolivia
#  66343                   Bolivia
#  66344                   Bolivia
#  66345                   Bolivia
#  33870    Bosnia and Herzegovina
#  Name: airline_country, Length: 68, dtype: object,
#  33869    Bosnia and Herzegovina
#  33872    Bosnia and Herzegovina
#  33867    Bosnia and Herzegovina
#  33866    Bosnia and Herzegovina
#  33865    Bosnia and Herzegovina
#                    ...
#  34447                    Brazil
#  34456                    Brazil
#  34438                    Brazil
#  34439                    Brazil
#  34440                    Brazil
#  Name: airline_country, Length: 68, dtype: object,
#  34441    Brazil
#  34442    Brazil
#  34443    Brazil
#  34444    Brazil
#  34445    Brazil
#            ...
#  34267    Brazil
#  34266    Brazil
#  34265    Brazil
#  34264    Brazil
#  34263    Brazil
#  Name: airline_country, Length: 68, dtype: object,
#  34262    Brazil
#  34437    Brazil
#  34260    Brazil
#  34259    Brazil
#  34258    Brazil
#            ...
#  34345    Brazil
#  34344    Brazil
#  34343    Brazil
#  34342    Brazil
#  34341    Brazil
#  Name: airline_country, Length: 68, dtype: object,
#  34340    Brazil
#  34339    Brazil
#  34338    Brazil
#  34337    Brazil
#  34336    Brazil
#            ...
#  34325    Brazil
#  34324    Brazil
#  34323    Brazil
#  34322    Brazil
#  34321    Brazil
#  Name: airline_country, Length: 68, dtype: object,
#  34320    Brazil
#  34319    Brazil
#  34318    Brazil
#  34317    Brazil
#  34316    Brazil
#            ...
#  8854     Brazil
#  8855     Brazil
#  8856     Brazil
#  8857     Brazil
#  8858     Brazil
#  Name: airline_country, Length: 68, dtype: object,
#  8859    Brazil
#  8860    Brazil
#  8861    Brazil
#  8862    Brazil
#  8863    Brazil
#           ...
#  8763    Brazil
#  8764    Brazil
#  8765    Brazil
#  8766    Brazil
#  8767    Brazil
#  Name: airline_country, Length: 68, dtype: object,
#  8768    Brazil
#  8769    Brazil
#  8770    Brazil
#  8771    Brazil
#  8772    Brazil
#           ...
#  8831    Brazil
#  8832    Brazil
#  8833    Brazil
#  8834    Brazil
#  8835    Brazil
#  Name: airline_country, Length: 68, dtype: object,
#  8836    Brazil
#  8837    Brazil
#  8827    Brazil
#  8814    Brazil
#  8813    Brazil
#           ...
#  8659    Brazil
#  8658    Brazil
#  8657    Brazil
#  8656    Brazil
#  8655    Brazil
#  Name: airline_country, Length: 68, dtype: object,
#  8654     Brazil
#  8653     Brazil
#  8652     Brazil
#  8651     Brazil
#  8650     Brazil
#            ...
#  63386    Brazil
#  63385    Brazil
#  63384    Brazil
#  63383    Brazil
#  8612     Brazil
#  Name: airline_country, Length: 68, dtype: object,
#  8699    Brazil
#  2953    Brazil
#  2951    Brazil
#  8670    Brazil
#  8669    Brazil
#           ...
#  2936    Brazil
#  2937    Brazil
#  2938    Brazil
#  2928    Brazil
#  2939    Brazil
#  Name: airline_country, Length: 68, dtype: object,
#  2941     Brazil
#  2942     Brazil
#  2943     Brazil
#  2944     Brazil
#  2945     Brazil
#            ...
#  44120    Brazil
#  44121    Brazil
#  44122    Brazil
#  44123    Brazil
#  44124    Brazil
#  Name: airline_country, Length: 68, dtype: object,
#  44097    Brazil
#  44096    Brazil
#  44095    Brazil
#  44094    Brazil
#  43307    Brazil
#            ...
#  44188    Brazil
#  44175    Brazil
#  43306    Brazil
#  44159    Brazil
#  44157    Brazil
#  Name: airline_country, Length: 68, dtype: object,
#  44129    Brazil
#  44130    Brazil
#  44131    Brazil
#  44132    Brazil
#  44133    Brazil
#            ...
#  47890    Brazil
#  66226    Brazil
#  66225    Brazil
#  66224    Brazil
#  7807     Brazil
#  Name: airline_country, Length: 68, dtype: object,
#  7808     Brazil
#  7809     Brazil
#  37831    Brazil
#  37832    Brazil
#  37833    Brazil
#            ...
#  8550     Brazil
#  8551     Brazil
#  8552     Brazil
#  8553     Brazil
#  8554     Brazil
#  Name: airline_country, Length: 68, dtype: object,
#  8555     Brazil
#  8556     Brazil
#  8557     Brazil
#  8558     Brazil
#  8559     Brazil
#            ...
#  34157    Brazil
#  3309     Brazil
#  3308     Brazil
#  3292     Brazil
#  3307     Brazil
#  Name: airline_country, Length: 68, dtype: object,
#  3305                     Brazil
#  3304                     Brazil
#  3303                     Brazil
#  3302                     Brazil
#  3301                     Brazil
#                    ...
#  34196                    Brazil
#  34151                    Brazil
#  65582    British Virgin Islands
#  65581    British Virgin Islands
#  65580    British Virgin Islands
#  Name: airline_country, Length: 68, dtype: object,
#  65579    British Virgin Islands
#  65578    British Virgin Islands
#  65577    British Virgin Islands
#  15365                    Brunei
#  15359                    Brunei
#                    ...
#  24575                  Bulgaria
#  24582                  Bulgaria
#  24540                  Bulgaria
#  24541                  Bulgaria
#  24542                  Bulgaria
#  Name: airline_country, Length: 68, dtype: object,
#  24543    Bulgaria
#  24544    Bulgaria
#  24545    Bulgaria
#  24581    Bulgaria
#  24547    Bulgaria
#             ...
#  2409        Burma
#  2408        Burma
#  2407        Burma
#  2410        Burma
#  2405        Burma
#  Name: airline_country, Length: 68, dtype: object,
#  12580      Burma
#  2404       Burma
#  2403       Burma
#  2402       Burma
#  2398       Burma
#            ...
#  28525    Burundi
#  28730    Burundi
#  28698    Burundi
#  28729    Burundi
#  28727    Burundi
#  Name: airline_country, Length: 68, dtype: object,
#  28700    Burundi
#  28701    Burundi
#  28702    Burundi
#  28703    Burundi
#  28704    Burundi
#            ...
#  28633    Burundi
#  28632    Burundi
#  28631    Burundi
#  28630    Burundi
#  28629    Burundi
#  Name: airline_country, Length: 68, dtype: object,
#  28628    Burundi
#  28627    Burundi
#  28626    Burundi
#  28625    Burundi
#  28624    Burundi
#            ...
#  28794    Burundi
#  28793    Burundi
#  28792    Burundi
#  28791    Burundi
#  28790    Burundi
#  Name: airline_country, Length: 68, dtype: object,
#  28789    Burundi
#  28788    Burundi
#  28787    Burundi
#  28786    Burundi
#  28785    Burundi
#            ...
#  28555    Burundi
#  28556    Burundi
#  28557    Burundi
#  28558    Burundi
#  28559    Burundi
#  Name: airline_country, Length: 68, dtype: object,
#  28560    Burundi
#  28561    Burundi
#  28562    Burundi
#  28563    Burundi
#  28564    Burundi
#            ...
#  28853    Burundi
#  28854    Burundi
#  28658    Burundi
#  28659    Burundi
#  28847    Burundi
#  Name: airline_country, Length: 68, dtype: object,
#  28835     Burundi
#  61360    Cambodia
#  61375    Cambodia
#  61361    Cambodia
#  61362    Cambodia
#             ...
#  60714    Cameroon
#  60713    Cameroon
#  46716    Cameroon
#  46711    Cameroon
#  46718    Cameroon
#  Name: airline_country, Length: 68, dtype: object,
#  46717    Cameroon
#  46720    Cameroon
#  46731    Cameroon
#  46732    Cameroon
#  46733    Cameroon
#             ...
#  8044       Canada
#  8069       Canada
#  8068       Canada
#  8066       Canada
#  8043       Canada
#  Name: airline_country, Length: 68, dtype: object,
#  8031    Canada
#  8041    Canada
#  7985    Canada
#  7986    Canada
#  7987    Canada
#           ...
#  8006    Canada
#  8007    Canada
#  8008    Canada
#  8009    Canada
#  8010    Canada
#  Name: airline_country, Length: 68, dtype: object,
#  8011    Canada
#  8022    Canada
#  8012    Canada
#  8014    Canada
#  8015    Canada
#           ...
#  8207    Canada
#  8206    Canada
#  8205    Canada
#  8191    Canada
#  8192    Canada
#  Name: airline_country, Length: 68, dtype: object,
#  8193    Canada
#  8194    Canada
#  8195    Canada
#  8196    Canada
#  8189    Canada
#           ...
#  8149    Canada
#  8148    Canada
#  8147    Canada
#  8146    Canada
#  8145    Canada
#  Name: airline_country, Length: 68, dtype: object,
#  8131    Canada
#  8132    Canada
#  8133    Canada
#  8134    Canada
#  8135    Canada
#           ...
#  7828    Canada
#  7827    Canada
#  2063    Canada
#  7826    Canada
#  7824    Canada
#  Name: airline_country, Length: 68, dtype: object,
#  7823    Canada
#  7822    Canada
#  7821    Canada
#  7820    Canada
#  7819    Canada
#           ...
#  2079    Canada
#  2080    Canada
#  2098    Canada
#  2081    Canada
#  2083    Canada
#  Name: airline_country, Length: 68, dtype: object,
#  2084    Canada
#  2085    Canada
#  2086    Canada
#  2087    Canada
#  2088    Canada
#           ...
#  7948    Canada
#  7947    Canada
#  7929    Canada
#  7946    Canada
#  7944    Canada
#  Name: airline_country, Length: 68, dtype: object,
#  7943     Canada
#  7942     Canada
#  7941     Canada
#  7940     Canada
#  7939     Canada
#            ...
#  7880     Canada
#  7879     Canada
#  54020    Canada
#  7878     Canada
#  7876     Canada
#  Name: airline_country, Length: 68, dtype: object,
#  7875     Canada
#  7874     Canada
#  7873     Canada
#  7872     Canada
#  7871     Canada
#            ...
#  15355    Canada
#  15354    Canada
#  53921    Canada
#  15353    Canada
#  15351    Canada
#  Name: airline_country, Length: 68, dtype: object,
#  15350    Canada
#  15349    Canada
#  15348    Canada
#  380      Canada
#  379      Canada
#            ...
#  53970    Canada
#  53971    Canada
#  8510     Canada
#  53972    Canada
#  53974    Canada
#  Name: airline_country, Length: 68, dtype: object,
#  53975    Canada
#  53976    Canada
#  53977    Canada
#  53978    Canada
#  53979    Canada
#            ...
#  35405    Canada
#  35406    Canada
#  35424    Canada
#  35407    Canada
#  35409    Canada
#  Name: airline_country, Length: 68, dtype: object,
#  35410    Canada
#  35411    Canada
#  35412    Canada
#  35413    Canada
#  35414    Canada
#            ...
#  31056    Canada
#  31057    Canada
#  31058    Canada
#  31059    Canada
#  31060    Canada
#  Name: airline_country, Length: 68, dtype: object,
#  31074    Canada
#  31073    Canada
#  31072    Canada
#  31071    Canada
#  31070    Canada
#            ...
#  8325     Canada
#  8324     Canada
#  8323     Canada
#  8305     Canada
#  8322     Canada
#  Name: airline_country, Length: 68, dtype: object,
#  8320    Canada
#  8319    Canada
#  8318    Canada
#  8317    Canada
#  8316    Canada
#           ...
#  8257    Canada
#  8256    Canada
#  8255    Canada
#  8254    Canada
#  8253    Canada
#  Name: airline_country, Length: 68, dtype: object,
#  8252     Canada
#  53995    Canada
#  53994    Canada
#  53993    Canada
#  53992    Canada
#            ...
#  8463     Canada
#  8462     Canada
#  8461     Canada
#  8460     Canada
#  8442     Canada
#  Name: airline_country, Length: 68, dtype: object,
#  8459    Canada
#  8457    Canada
#  8456    Canada
#  8455    Canada
#  8454    Canada
#           ...
#  8395    Canada
#  8394    Canada
#  8393    Canada
#  8392    Canada
#  8391    Canada
#  Name: airline_country, Length: 68, dtype: object,
#  8390     Canada
#  8389     Canada
#  8375     Canada
#  8376     Canada
#  8377     Canada
#            ...
#  64731    Canada
#  64732    Canada
#  64733    Canada
#  64734    Canada
#  64727    Canada
#  Name: airline_country, Length: 68, dtype: object,
#  64735    Canada
#  64737    Canada
#  64738    Canada
#  64739    Canada
#  64740    Canada
#            ...
#  64672    Canada
#  64673    Canada
#  64674    Canada
#  64675    Canada
#  64676    Canada
#  Name: airline_country, Length: 68, dtype: object,
#  64677    Canada
#  64670    Canada
#  2520     Canada
#  2518     Canada
#  2517     Canada
#            ...
#  64866    Canada
#  64848    Canada
#  64846    Canada
#  64830    Canada
#  64831    Canada
#  Name: airline_country, Length: 68, dtype: object,
#  64832    Canada
#  64833    Canada
#  64834    Canada
#  64835    Canada
#  64836    Canada
#            ...
#  64773    Canada
#  64774    Canada
#  64775    Canada
#  64767    Canada
#  64776    Canada
#  Name: airline_country, Length: 68, dtype: object,
#  64778    Canada
#  64779    Canada
#  64780    Canada
#  64781    Canada
#  64782    Canada
#            ...
#  64801    Canada
#  64802    Canada
#  64803    Canada
#  64804    Canada
#  64805    Canada
#  Name: airline_country, Length: 68, dtype: object,
#  64827    Canada
#  64660    Canada
#  2519     Canada
#  64658    Canada
#  64877    Canada
#            ...
#  64581    Canada
#  45626    Canada
#  45625    Canada
#  45624    Canada
#  3211     Canada
#  Name: airline_country, Length: 68, dtype: object,
#  3212     Canada
#  3213     Canada
#  3214     Canada
#  3215     Canada
#  3216     Canada
#            ...
#  66033    Canada
#  66034    Canada
#  66035    Canada
#  66036    Canada
#  66037    Canada
#  Name: airline_country, Length: 68, dtype: object,
#  66038    Canada
#  66039    Canada
#  66040    Canada
#  64598    Canada
#  66042    Canada
#            ...
#  66041    Canada
#  64624    Canada
#  66078    Canada
#  66079    Canada
#  64610    Canada
#  Name: airline_country, Length: 68, dtype: object,
#  66081            Canada
#  64611            Canada
#  66082            Canada
#  64612            Canada
#  66083            Canada
#                ...
#  37443    Cayman Islands
#  37441    Cayman Islands
#  37449    Cayman Islands
#  37444    Cayman Islands
#  37450    Cayman Islands
#  Name: airline_country, Length: 68, dtype: object,
#  37457    Cayman Islands
#  37452    Cayman Islands
#  37451    Cayman Islands
#  37463    Cayman Islands
#  37462    Cayman Islands
#                ...
#  37617             Chile
#  37570             Chile
#  37569             Chile
#  37568             Chile
#  37567             Chile
#  Name: airline_country, Length: 68, dtype: object,
#  37566    Chile
#  37565    Chile
#  37571    Chile
#  37564    Chile
#  37562    Chile
#           ...
#  37594    Chile
#  37595    Chile
#  37596    Chile
#  37597    Chile
#  37599    Chile
#  Name: airline_country, Length: 68, dtype: object,
#  37669    Chile
#  37766    Chile
#  37671    Chile
#  37794    Chile
#  37793    Chile
#           ...
#  37827    Chile
#  30594    Chile
#  30596    Chile
#  37780    Chile
#  37779    Chile
#  Name: airline_country, Length: 68, dtype: object,
#  37778    Chile
#  37777    Chile
#  37776    Chile
#  37775    Chile
#  37774    Chile
#           ...
#  37706    Chile
#  37707    Chile
#  37708    Chile
#  37709    Chile
#  37829    Chile
#  Name: airline_country, Length: 68, dtype: object,
#  37711    Chile
#  37712    Chile
#  37713    Chile
#  37714    Chile
#  37715    Chile
#           ...
#  37749    Chile
#  37748    Chile
#  37747    Chile
#  37746    Chile
#  2015     Chile
#  Name: airline_country, Length: 68, dtype: object,
#  37744    Chile
#  37745    Chile
#  37739    Chile
#  37737    Chile
#  37736    Chile
#           ...
#  16234    China
#  16232    China
#  16201    China
#  16200    China
#  16199    China
#  Name: airline_country, Length: 68, dtype: object,
#  16198    China
#  16197    China
#  16196    China
#  16195    China
#  16233    China
#           ...
#  16057    China
#  16056    China
#  16055    China
#  16054    China
#  16053    China
#  Name: airline_country, Length: 68, dtype: object,
#  16052    China
#  16051    China
#  16050    China
#  16049    China
#  16260    China
#           ...
#  30949    China
#  30950    China
#  30951    China
#  30953    China
#  16065    China
#  Name: airline_country, Length: 68, dtype: object,
#  16066    China
#  16067    China
#  16145    China
#  16144    China
#  16143    China
#           ...
#  16083    China
#  16082    China
#  16081    China
#  16080    China
#  16079    China
#  Name: airline_country, Length: 68, dtype: object,
#  16078    China
#  16077    China
#  16076    China
#  16075    China
#  16074    China
#           ...
#  16739    China
#  16738    China
#  16719    China
#  16720    China
#  16721    China
#  Name: airline_country, Length: 68, dtype: object,
#  16722    China
#  16723    China
#  16724    China
#  16725    China
#  16726    China
#           ...
#  16716    China
#  16715    China
#  16651    China
#  16652    China
#  16653    China
#  Name: airline_country, Length: 68, dtype: object,
#  16654    China
#  16655    China
#  16656    China
#  16657    China
#  16658    China
#           ...
#  16694    China
#  16692    China
#  16673    China
#  16674    China
#  16675    China
#  Name: airline_country, Length: 68, dtype: object,
#  16676    China
#  16677    China
#  16678    China
#  16679    China
#  16680    China
#           ...
#  41880    China
#  41881    China
#  41903    China
#  41904    China
#  41905    China
#  Name: airline_country, Length: 68, dtype: object,
#  41906    China
#  41907    China
#  41908    China
#  41909    China
#  41910    China
#           ...
#  16829    China
#  16828    China
#  16809    China
#  16810    China
#  16811    China
#  Name: airline_country, Length: 68, dtype: object,
#  16812    China
#  16813    China
#  16814    China
#  16815    China
#  16816    China
#           ...
#  16262    China
#  16626    China
#  16624    China
#  16378    China
#  16379    China
#  Name: airline_country, Length: 68, dtype: object,
#  16380    China
#  16381    China
#  16382    China
#  16383    China
#  16384    China
#           ...
#  16420    China
#  16419    China
#  16400    China
#  16401    China
#  16402    China
#  Name: airline_country, Length: 68, dtype: object,
#  16403    China
#  16404    China
#  16405    China
#  16406    China
#  16407    China
#           ...
#  16307    China
#  16308    China
#  16332    China
#  16333    China
#  16334    China
#  Name: airline_country, Length: 68, dtype: object,
#  16335    China
#  16336    China
#  16337    China
#  16338    China
#  16339    China
#           ...
#  16557    China
#  16556    China
#  16537    China
#  16538    China
#  16539    China
#  Name: airline_country, Length: 68, dtype: object,
#  16540    China
#  16541    China
#  16542    China
#  16543    China
#  16544    China
#           ...
#  16625    China
#  16535    China
#  16533    China
#  16468    China
#  16469    China
#  Name: airline_country, Length: 68, dtype: object,
#  16470    China
#  16471    China
#  16472    China
#  16473    China
#  16474    China
#           ...
#  16534    China
#  16512    China
#  16510    China
#  16490    China
#  16491    China
#  Name: airline_country, Length: 68, dtype: object,
#  16492    China
#  16493    China
#  16494    China
#  16495    China
#  16496    China
#           ...
#  25576    China
#  25575    China
#  25574    China
#  25573    China
#  25572    China
#  Name: airline_country, Length: 68, dtype: object,
#  41608    China
#  40464    China
#  40463    China
#  40178    China
#  40442    China
#           ...
#  41532    China
#  41533    China
#  41534    China
#  41535    China
#  41536    China
#  Name: airline_country, Length: 68, dtype: object,
#  41537    China
#  41538    China
#  41539    China
#  41540    China
#  41541    China
#           ...
#  41569    China
#  41567    China
#  41550    China
#  25586    China
#  25585    China
#  Name: airline_country, Length: 68, dtype: object,
#  25584    China
#  25583    China
#  25582    China
#  41551    China
#  41552    China
#           ...
#  41739    China
#  41740    China
#  41741    China
#  41742    China
#  41743    China
#  Name: airline_country, Length: 68, dtype: object,
#  41744    China
#  41745    China
#  41735    China
#  41772    China
#  41773    China
#           ...
#  41652    China
#  41653    China
#  41654    China
#  41655    China
#  41656    China
#  Name: airline_country, Length: 68, dtype: object,
#  41657    China
#  41658    China
#  41659    China
#  41660    China
#  41661    China
#           ...
#  41709    China
#  41721    China
#  41696    China
#  41694    China
#  41672    China
#  Name: airline_country, Length: 68, dtype: object,
#  41673    China
#  41674    China
#  41675    China
#  41676    China
#  41677    China
#           ...
#  25704    China
#  25703    China
#  25702    China
#  25701    China
#  25700    China
#  Name: airline_country, Length: 68, dtype: object,
#  25699    China
#  25698    China
#  25697    China
#  25696    China
#  25706    China
#           ...
#  41344    China
#  41345    China
#  41346    China
#  41347    China
#  41348    China
#  Name: airline_country, Length: 68, dtype: object,
#  41349    China
#  41350    China
#  41351    China
#  41352    China
#  41353    China
#           ...
#  25723    China
#  25722    China
#  25732    China
#  25720    China
#  41390    China
#  Name: airline_country, Length: 68, dtype: object,
#  41388    China
#  41366    China
#  41367    China
#  41368    China
#  41369    China
#           ...
#  40167    China
#  40169    China
#  40170    China
#  40171    China
#  40172    China
#  Name: airline_country, Length: 68, dtype: object,
#  40173    China
#  40174    China
#  40175    China
#  40176    China
#  40177    China
#           ...
#  25629    China
#  25628    China
#  25627    China
#  25626    China
#  25625    China
#  Name: airline_country, Length: 68, dtype: object,
#  25624    China
#  25623    China
#  25622    China
#  25621    China
#  25631    China
#           ...
#  40148    China
#  40149    China
#  40150    China
#  40151    China
#  40152    China
#  Name: airline_country, Length: 68, dtype: object,
#  40142    China
#  40103    China
#  40129    China
#  40127    China
#  40105    China
#           ...
#  31279    China
#  31278    China
#  31240    China
#  31277    China
#  31275    China
#  Name: airline_country, Length: 68, dtype: object,
#  31274    China
#  31273    China
#  31272    China
#  31271    China
#  31270    China
#           ...
#  31289    China
#  31291    China
#  31364    China
#  31363    China
#  31362    China
#  Name: airline_country, Length: 68, dtype: object,
#  31361    China
#  31360    China
#  31359    China
#  31358    China
#  31357    China
#           ...
#  31298    China
#  31297    China
#  31296    China
#  31295    China
#  31294    China
#  Name: airline_country, Length: 68, dtype: object,
#  31293    China
#  31292    China
#  31302    China
#  31290    China
#  31315    China
#           ...
#  46094    China
#  46095    China
#  46096    China
#  46097    China
#  40342    China
#  Name: airline_country, Length: 68, dtype: object,
#  46098    China
#  46100    China
#  46101    China
#  46102    China
#  40374    China
#           ...
#  31019    China
#  31186    China
#  46086    China
#  46084    China
#  31158    China
#  Name: airline_country, Length: 68, dtype: object,
#  31157    China
#  31156    China
#  31155    China
#  31154    China
#  31153    China
#           ...
#  46075    China
#  46076    China
#  46077    China
#  46078    China
#  46079    China
#  Name: airline_country, Length: 68, dtype: object,
#  46080    China
#  46081    China
#  46082    China
#  46083    China
#  46073    China
#           ...
#  40389    China
#  40388    China
#  40387    China
#  40386    China
#  40385    China
#  Name: airline_country, Length: 68, dtype: object,
#  40384    China
#  46041    China
#  40383    China
#  40381    China
#  40380    China
#           ...
#  31616    China
#  31615    China
#  31625    China
#  31588    China
#  40395    China
#  Name: airline_country, Length: 68, dtype: object,
#  40397    China
#  31678    China
#  31677    China
#  31676    China
#  31675    China
#           ...
#  40409    China
#  40407    China
#  40406    China
#  40405    China
#  40404    China
#  Name: airline_country, Length: 68, dtype: object,
#  40403    China
#  40402    China
#  40401    China
#  40400    China
#  40399    China
#           ...
#  31478    China
#  31477    China
#  31476    China
#  31475    China
#  31474    China
#  Name: airline_country, Length: 68, dtype: object,
#  31473    China
#  31472    China
#  31471    China
#  31433    China
#  31470    China
#           ...
#  31411    China
#  31410    China
#  31409    China
#  31408    China
#  31418    China
#  Name: airline_country, Length: 68, dtype: object,
#  31482    China
#  31483    China
#  31484    China
#  31558    China
#  31557    China
#           ...
#  31498    China
#  31497    China
#  31507    China
#  31496    China
#  31494    China
#  Name: airline_country, Length: 68, dtype: object,
#  31493    China
#  31492    China
#  31491    China
#  31490    China
#  31489    China
#           ...
#  18735    China
#  18736    China
#  18737    China
#  18738    China
#  18739    China
#  Name: airline_country, Length: 68, dtype: object,
#  18740    China
#  18741    China
#  18742    China
#  18743    China
#  18756    China
#           ...
#  18793    China
#  18827    China
#  18733    China
#  18731    China
#  18663    China
#  Name: airline_country, Length: 68, dtype: object,
#  18664    China
#  18665    China
#  18666    China
#  18667    China
#  18668    China
#           ...
#  18727    China
#  18728    China
#  18729    China
#  18730    China
#  18721    China
#  Name: airline_country, Length: 68, dtype: object,
#  18685    China
#  18709    China
#  18707    China
#  18687    China
#  18688    China
#           ...
#  18939    China
#  18940    China
#  18941    China
#  18942    China
#  18943    China
#  Name: airline_country, Length: 68, dtype: object,
#  18944    China
#  18945    China
#  18946    China
#  18937    China
#  18926    China
#           ...
#  18863    China
#  18854    China
#  18864    China
#  18866    China
#  18867    China
#  Name: airline_country, Length: 68, dtype: object,
#  18868    China
#  18869    China
#  18870    China
#  18871    China
#  18872    China
#           ...
#  18883    China
#  18884    China
#  18885    China
#  18886    China
#  18887    China
#  Name: airline_country, Length: 68, dtype: object,
#  18900    China
#  18888    China
#  18890    China
#  18891    China
#  18892    China
#           ...
#  49149    China
#  49150    China
#  49151    China
#  49152    China
#  49153    China
#  Name: airline_country, Length: 68, dtype: object,
#  49154    China
#  49155    China
#  49156    China
#  49157    China
#  49148    China
#           ...
#  49015    China
#  49025    China
#  49003    China
#  49001    China
#  48981    China
#  Name: airline_country, Length: 68, dtype: object,
#  48982    China
#  48983    China
#  48984    China
#  48985    China
#  48986    China
#           ...
#  49045    China
#  49046    China
#  49047    China
#  49048    China
#  49039    China
#  Name: airline_country, Length: 68, dtype: object,
#  49170    China
#  49171    China
#  49172    China
#  19510    China
#  19509    China
#           ...
#  18627    China
#  18628    China
#  18629    China
#  18630    China
#  18631    China
#  Name: airline_country, Length: 68, dtype: object,
#  18632    China
#  18633    China
#  18634    China
#  18625    China
#  18589    China
#           ...
#  49181    China
#  49194    China
#  49182    China
#  49184    China
#  49185    China
#  Name: airline_country, Length: 68, dtype: object,
#  49186    China
#  49187    China
#  49188    China
#  49189    China
#  49190    China
#           ...
#  19455    China
#  19454    China
#  19453    China
#  19452    China
#  19451    China
#  Name: airline_country, Length: 68, dtype: object,
#  19450    China
#  19459    China
#  19449    China
#  19447    China
#  19446    China
#           ...
#  42104    China
#  42084    China
#  42085    China
#  42086    China
#  42087    China
#  Name: airline_country, Length: 68, dtype: object,
#  42088    China
#  42089    China
#  42090    China
#  42091    China
#  42092    China
#           ...
#  19373    China
#  42055    China
#  19485    China
#  19505    China
#  19397    China
#  Name: airline_country, Length: 68, dtype: object,
#  42077    China
#  42078    China
#  19504    China
#  19503    China
#  19502    China
#           ...
#  42267    China
#  42268    China
#  42269    China
#  42270    China
#  42271    China
#  Name: airline_country, Length: 68, dtype: object,
#  42262    China
#  42272    China
#  42250    China
#  42248    China
#  42228    China
#           ...
#  42287    China
#  19408    China
#  19409    China
#  19410    China
#  19411    China
#  Name: airline_country, Length: 68, dtype: object,
#  19412    China
#  19413    China
#  19414    China
#  19415    China
#  42286    China
#           ...
#  42211    China
#  42212    China
#  42203    China
#  42213    China
#  42215    China
#  Name: airline_country, Length: 68, dtype: object,
#  42216    China
#  42217    China
#  42218    China
#  42219    China
#  42220    China
#           ...
#  19122    China
#  19123    China
#  19124    China
#  19125    China
#  19126    China
#  Name: airline_country, Length: 68, dtype: object,
#  19127    China
#  19140    China
#  19128    China
#  19130    China
#  19131    China
#           ...
#  19115    China
#  19047    China
#  19048    China
#  19049    China
#  19050    China
#  Name: airline_country, Length: 68, dtype: object,
#  19051    China
#  19052    China
#  19053    China
#  19054    China
#  19055    China
#           ...
#  19114    China
#  19105    China
#  19069    China
#  19093    China
#  19091    China
#  Name: airline_country, Length: 68, dtype: object,
#  19071    China
#  19072    China
#  19073    China
#  19074    China
#  19075    China
#           ...
#  19327    China
#  19328    China
#  19329    China
#  19330    China
#  19331    China
#  Name: airline_country, Length: 68, dtype: object,
#  19322    China
#  19311    China
#  19357    China
#  19359    China
#  42021    China
#           ...
#  19250    China
#  19251    China
#  19252    China
#  19253    China
#  19254    China
#  Name: airline_country, Length: 68, dtype: object,
#  19255    China
#  19256    China
#  19257    China
#  19258    China
#  19249    China
#           ...
#  19270    China
#  19271    China
#  19272    China
#  19273    China
#  19274    China
#  Name: airline_country, Length: 68, dtype: object,
#  19275    China
#  19276    China
#  19277    China
#  19278    China
#  19279    China
#           ...
#  40237    China
#  40238    China
#  40239    China
#  40240    China
#  40241    China
#  Name: airline_country, Length: 68, dtype: object,
#  40242    China
#  40243    China
#  40234    China
#  40244    China
#  40246    China
#           ...
#  17214    China
#  17212    China
#  17192    China
#  17193    China
#  17194    China
#  Name: airline_country, Length: 68, dtype: object,
#  17195    China
#  17196    China
#  17197    China
#  17198    China
#  17199    China
#           ...
#  17258    China
#  17259    China
#  17250    China
#  17191    China
#  29257    China
#  Name: airline_country, Length: 68, dtype: object,
#  29259    China
#  18095    China
#  18096    China
#  18097    China
#  18098    China
#           ...
#  18157    China
#  18158    China
#  18159    China
#  18160    China
#  18161    China
#  Name: airline_country, Length: 68, dtype: object,
#  18162    China
#  18153    China
#  18117    China
#  18141    China
#  18139    China
#           ...
#  40253    China
#  40255    China
#  40256    China
#  40257    China
#  40258    China
#  Name: airline_country, Length: 68, dtype: object,
#  40259    China
#  40260    China
#  40261    China
#  40262    China
#  40263    China
#           ...
#  16932    China
#  16933    China
#  16934    China
#  16925    China
#  16935    China
#  Name: airline_country, Length: 68, dtype: object,
#  16937    China
#  16938    China
#  16939    China
#  16940    China
#  16941    China
#           ...
#  16952    China
#  16953    China
#  16954    China
#  16955    China
#  16956    China
#  Name: airline_country, Length: 68, dtype: object,
#  16957    China
#  16958    China
#  16971    China
#  16959    China
#  16961    China
#           ...
#  41971    China
#  41973    China
#  41998    China
#  41999    China
#  42000    China
#  Name: airline_country, Length: 68, dtype: object,
#  42001    China
#  42002    China
#  42003    China
#  42004    China
#  16885    China
#           ...
#  17138    China
#  17139    China
#  17130    China
#  17140    China
#  17118    China
#  Name: airline_country, Length: 68, dtype: object,
#  17116    China
#  17096    China
#  17097    China
#  17098    China
#  17099    China
#           ...
#  17158    China
#  17159    China
#  17160    China
#  17161    China
#  17162    China
#  Name: airline_country, Length: 68, dtype: object,
#  17163    China
#  17154    China
#  17094    China
#  17093    China
#  17092    China
#           ...
#  17081    China
#  17083    China
#  17084    China
#  17085    China
#  17086    China
#  Name: airline_country, Length: 68, dtype: object,
#  17087    China
#  17088    China
#  17089    China
#  17090    China
#  17091    China
#           ...
#  42569    China
#  42568    China
#  42567    China
#  42566    China
#  42553    China
#  Name: airline_country, Length: 68, dtype: object,
#  42565    China
#  42563    China
#  42562    China
#  42561    China
#  42560    China
#           ...
#  29274    China
#  29275    China
#  29276    China
#  29277    China
#  29278    China
#  Name: airline_country, Length: 68, dtype: object,
#  29279    China
#  29280    China
#  29281    China
#  29272    China
#  29282    China
#           ...
#  29295    China
#  29319    China
#  29317    China
#  29297    China
#  29298    China
#  Name: airline_country, Length: 68, dtype: object,
#  29299    China
#  29300    China
#  29301    China
#  29302    China
#  29303    China
#           ...
#  42364    China
#  42363    China
#  42362    China
#  42371    China
#  42382    China
#  Name: airline_country, Length: 68, dtype: object,
#  42336    China
#  42334    China
#  42309    China
#  42308    China
#  42307    China
#           ...
#  42441    China
#  42440    China
#  42439    China
#  42438    China
#  42437    China
#  Name: airline_country, Length: 68, dtype: object,
#  42436    China
#  42435    China
#  42444    China
#  42434    China
#  42456    China
#           ...
#  42421    China
#  42420    China
#  42419    China
#  42418    China
#  42417    China
#  Name: airline_country, Length: 68, dtype: object,
#  42416    China
#  42415    China
#  42414    China
#  42413    China
#  42412    China
#           ...
#  18339    China
#  18340    China
#  18341    China
#  18342    China
#  18343    China
#  Name: airline_country, Length: 68, dtype: object,
#  18334    China
#  18344    China
#  18346    China
#  18347    China
#  18348    China
#           ...
#  18167    China
#  18168    China
#  18169    China
#  18170    China
#  18171    China
#  Name: airline_country, Length: 68, dtype: object,
#  18172    China
#  18173    China
#  18174    China
#  18175    China
#  18188    China
#           ...
#  18225    China
#  18356    China
#  18357    China
#  18358    China
#  18480    China
#  Name: airline_country, Length: 68, dtype: object,
#  18481    China
#  18482    China
#  18483    China
#  18484    China
#  18485    China
#           ...
#  18544    China
#  18545    China
#  18546    China
#  18547    China
#  18538    China
#  Name: airline_country, Length: 68, dtype: object,
#  18502    China
#  18526    China
#  18524    China
#  18504    China
#  18505    China
#           ...
#  18371    China
#  18372    China
#  18373    China
#  18374    China
#  18375    China
#  Name: airline_country, Length: 68, dtype: object,
#  18376    China
#  18377    China
#  18378    China
#  18369    China
#  18404    China
#           ...
#  37096    China
#  37097    China
#  37098    China
#  37099    China
#  67035    China
#  Name: airline_country, Length: 68, dtype: object,
#  67036    China
#  67037    China
#  67038    China
#  67039    China
#  67040    China
#           ...
#  67069    China
#  67070    China
#  67071    China
#  67072    China
#  67073    China
#  Name: airline_country, Length: 68, dtype: object,
#  67074    China
#  67075    China
#  67076    China
#  67077    China
#  67078    China
#           ...
#  765      China
#  764      China
# ...
#  25147    United States
#  25148    United States
#  25149    United States
#  25150    United States
#  Name: airline_country, Length: 67, dtype: object,
#  25151    United States
#  25152    United States
#  25153    United States
#  25154    United States
#  25155    United States
#               ...
#  24994    United States
#  24995    United States
#  24996    United States
#  24997    United States
#  24998    United States
#  Name: airline_country, Length: 67, dtype: object,
#  24975    United States
#  24999    United States
#  24974    United States
#  24972    United States
#  24949    United States
#               ...
#  25007    United States
#  25008    United States
#  25009    United States
#  25010    United States
#  25011    United States
#  Name: airline_country, Length: 67, dtype: object,
#  25012    United States
#  25013    United States
#  25055    United States
#  25014    United States
#  25016    United States
#               ...
#  59372    United States
#  59373    United States
#  59374    United States
#  59375    United States
#  59376    United States
#  Name: airline_country, Length: 67, dtype: object,
#  59377    United States
#  59378    United States
#  59380    United States
#  59355    United States
#  59407    United States
#               ...
#  59276    United States
#  59277    United States
#  59278    United States
#  59279    United States
#  59280    United States
#  Name: airline_country, Length: 67, dtype: object,
#  59281    United States
#  59282    United States
#  59283    United States
#  59284    United States
#  59285    United States
#               ...
#  59344    United States
#  59345    United States
#  59346    United States
#  59347    United States
#  59348    United States
#  Name: airline_country, Length: 67, dtype: object,
#  59349    United States
#  59350    United States
#  59351    United States
#  59328    United States
#  59327    United States
#               ...
#  59573    United States
#  59574    United States
#  59575    United States
#  59576    United States
#  59577    United States
#  Name: airline_country, Length: 67, dtype: object,
#  59578    United States
#  59579    United States
#  59580    United States
#  59581    United States
#  59582    United States
#               ...
#  59640    United States
#  59641    United States
#  59642    United States
#  59643    United States
#  59644    United States
#  Name: airline_country, Length: 67, dtype: object,
#  59645    United States
#  59646    United States
#  59647    United States
#  59648    United States
#  59649    United States
#               ...
#  59516    United States
#  59517    United States
#  59546    United States
#  59547    United States
#  59548    United States
#  Name: airline_country, Length: 67, dtype: object,
#  59549    United States
#  59550    United States
#  59551    United States
#  59552    United States
#  59553    United States
#               ...
#  58958    United States
#  58959    United States
#  58960    United States
#  58961    United States
#  58962    United States
#  Name: airline_country, Length: 67, dtype: object,
#  58963    United States
#  58964    United States
#  58965    United States
#  58966    United States
#  58967    United States
#               ...
#  59001    United States
#  58973    United States
#  59000    United States
#  58998    United States
#  58975    United States
#  Name: airline_country, Length: 67, dtype: object,
#  58976    United States
#  58977    United States
#  58978    United States
#  58979    United States
#  58980    United States
#               ...
#  58821    United States
#  58822    United States
#  58823    United States
#  58824    United States
#  58825    United States
#  Name: airline_country, Length: 67, dtype: object,
#  58826    United States
#  58827    United States
#  58828    United States
#  58829    United States
#  58830    United States
#               ...
#  58888    United States
#  58889    United States
#  58878    United States
#  59026    United States
#  59027    United States
#  Name: airline_country, Length: 67, dtype: object,
#  59028    United States
#  59165    United States
#  59166    United States
#  59167    United States
#  59168    United States
#               ...
#  59227    United States
#  59228    United States
#  59229    United States
#  59230    United States
#  59231    United States
#  Name: airline_country, Length: 67, dtype: object,
#  59232    United States
#  59233    United States
#  59234    United States
#  59235    United States
#  59236    United States
#               ...
#  59075    United States
#  59076    United States
#  59077    United States
#  59078    United States
#  59055    United States
#  Name: airline_country, Length: 67, dtype: object,
#  59079    United States
#  59054    United States
#  59052    United States
#  59029    United States
#  59030    United States
#               ...
#  59088    United States
#  59089    United States
#  59090    United States
#  59091    United States
#  59092    United States
#  Name: airline_country, Length: 67, dtype: object,
#  59093    United States
#  59135    United States
#  59094    United States
#  59096    United States
#  59097    United States
#               ...
#  57070    United States
#  57071    United States
#  57072    United States
#  57073    United States
#  57074    United States
#  Name: airline_country, Length: 67, dtype: object,
#  57075    United States
#  57076    United States
#  57077    United States
#  57066    United States
#  57107    United States
#               ...
#  57051    United States
#  57050    United States
#  56969    United States
#  56970    United States
#  56971    United States
#  Name: airline_country, Length: 67, dtype: object,
#  56972    United States
#  56973    United States
#  56974    United States
#  56975    United States
#  56976    United States
#               ...
#  57034    United States
#  57035    United States
#  57036    United States
#  57025    United States
#  57037    United States
#  Name: airline_country, Length: 67, dtype: object,
#  57039    United States
#  57040    United States
#  57041    United States
#  57042    United States
#  57043    United States
#               ...
#  57328    United States
#  57329    United States
#  57330    United States
#  57331    United States
#  57332    United States
#  Name: airline_country, Length: 67, dtype: object,
#  57333    United States
#  57322    United States
#  57308    United States
#  57307    United States
#  57306    United States
#               ...
#  57338    United States
#  57339    United States
#  57340    United States
#  57341    United States
#  57342    United States
#  Name: airline_country, Length: 67, dtype: object,
#  57343    United States
#  57344    United States
#  57345    United States
#  57346    United States
#  57347    United States
#               ...
#  57177    United States
#  57178    United States
#  57179    United States
#  57180    United States
#  57181    United States
#  Name: airline_country, Length: 67, dtype: object,
#  57182    United States
#  57183    United States
#  57184    United States
#  57185    United States
#  57186    United States
#               ...
#  57244    United States
#  57245    United States
#  57246    United States
#  57247    United States
#  57248    United States
#  Name: airline_country, Length: 67, dtype: object,
#  57222    United States
#  57390    United States
#  56938    United States
#  56936    United States
#  56627    United States
#               ...
#  56686    United States
#  56687    United States
#  56688    United States
#  56689    United States
#  56690    United States
#  Name: airline_country, Length: 67, dtype: object,
#  56691    United States
#  56692    United States
#  56693    United States
#  56694    United States
#  56683    United States
#               ...
#  56525    United States
#  56527    United States
#  56528    United States
#  56529    United States
#  56530    United States
#  Name: airline_country, Length: 67, dtype: object,
#  56531    United States
#  56532    United States
#  56533    United States
#  56534    United States
#  56535    United States
#               ...
#  56593    United States
#  56594    United States
#  56583    United States
#  56569    United States
#  56568    United States
#  Name: airline_country, Length: 67, dtype: object,
#  56567    United States
#  56542    United States
#  56543    United States
#  56544    United States
#  56545    United States
#               ...
#  56830    United States
#  56831    United States
#  56832    United States
#  56833    United States
#  56834    United States
#  Name: airline_country, Length: 67, dtype: object,
#  56835    United States
#  56836    United States
#  56837    United States
#  56838    United States
#  56839    United States
#               ...
#  56897    United States
#  56898    United States
#  56899    United States
#  56900    United States
#  56901    United States
#  Name: airline_country, Length: 67, dtype: object,
#  56902    United States
#  56903    United States
#  56904    United States
#  56905    United States
#  56906    United States
#               ...
#  56736    United States
#  56765    United States
#  56823    United States
#  56766    United States
#  56768    United States
#  Name: airline_country, Length: 67, dtype: object,
#  56798    United States
#  56799    United States
#  56800    United States
#  56801    United States
#  56802    United States
#               ...
#  57581    United States
#  57582    United States
#  57583    United States
#  57584    United States
#  57585    United States
#  Name: airline_country, Length: 67, dtype: object,
#  57586    United States
#  57587    United States
#  57588    United States
#  57589    United States
#  57590    United States
#               ...
#  57649    United States
#  57650    United States
#  57651    United States
#  57652    United States
#  57653    United States
#  Name: airline_country, Length: 67, dtype: object,
#  57654    United States
#  57655    United States
#  57656    United States
#  57657    United States
#  57658    United States
#               ...
#  57465    United States
#  57466    United States
#  57467    United States
#  57468    United States
#  57469    United States
#  Name: airline_country, Length: 67, dtype: object,
#  57470    United States
#  57471    United States
#  57472    United States
#  57473    United States
#  57474    United States
#               ...
#  57532    United States
#  57533    United States
#  57534    United States
#  57535    United States
#  57536    United States
#  Name: airline_country, Length: 67, dtype: object,
#  57537    United States
#  57538    United States
#  57539    United States
#  57540    United States
#  57513    United States
#               ...
#  57850    United States
#  57851    United States
#  57852    United States
#  57853    United States
#  57854    United States
#  Name: airline_country, Length: 67, dtype: object,
#  57827    United States
#  57826    United States
#  57825    United States
#  57824    United States
#  57796    United States
#               ...
#  57917    United States
#  57890    United States
#  57889    United States
#  57888    United States
#  57887    United States
#  Name: airline_country, Length: 67, dtype: object,
#  57859    United States
#  57860    United States
#  57861    United States
#  57862    United States
#  57863    United States
#               ...
#  57698    United States
#  57670    United States
#  57671    United States
#  57672    United States
#  57673    United States
#  Name: airline_country, Length: 67, dtype: object,
#  57674    United States
#  57675    United States
#  57676    United States
#  57677    United States
#  57678    United States
#               ...
#  57736    United States
#  57737    United States
#  57738    United States
#  57739    United States
#  57740    United States
#  Name: airline_country, Length: 67, dtype: object,
#  57741    United States
#  57742    United States
#  57743    United States
#  57744    United States
#  57745    United States
#               ...
#  2017           Uruguay
#  2023           Uruguay
#  32079       Uzbekistan
#  32075       Uzbekistan
#  32080       Uzbekistan
#  Name: airline_country, Length: 67, dtype: object,
#  32081    Uzbekistan
#  32082    Uzbekistan
#  32083    Uzbekistan
#  32078    Uzbekistan
#  32077    Uzbekistan
#              ...
#  32061    Uzbekistan
#  32018    Uzbekistan
#  32019    Uzbekistan
#  32020    Uzbekistan
#  32021    Uzbekistan
#  Name: airline_country, Length: 67, dtype: object,
#  32022    Uzbekistan
#  32023    Uzbekistan
#  31994    Uzbekistan
#  32017    Uzbekistan
#  31993    Uzbekistan
#              ...
#  31980    Uzbekistan
#  31979    Uzbekistan
#  32028    Uzbekistan
#  32029    Uzbekistan
#  32030    Uzbekistan
#  Name: airline_country, Length: 67, dtype: object,
#  32031    Uzbekistan
#  32032    Uzbekistan
#  32033    Uzbekistan
#  32034    Uzbekistan
#  32035    Uzbekistan
#              ...
#  42658       Vanuatu
#  42659       Vanuatu
#  42721       Vanuatu
#  42661       Vanuatu
#  42662       Vanuatu
#  Name: airline_country, Length: 67, dtype: object,
#  42663      Vanuatu
#  42664      Vanuatu
#  42665      Vanuatu
#  42666      Vanuatu
#  42667      Vanuatu
#             ...
#  60738    Venezuela
#  60737    Venezuela
#  60736    Venezuela
#  60745    Venezuela
#  60735    Venezuela
#  Name: airline_country, Length: 67, dtype: object,
#  60733    Venezuela
#  60732    Venezuela
#  60731    Venezuela
#  60730    Venezuela
#  60729    Venezuela
#             ...
#  60719    Venezuela
#  60718    Venezuela
#  60717    Venezuela
#  60716    Venezuela
#  48363    Venezuela
#  Name: airline_country, Length: 67, dtype: object,
#  48362    Venezuela
#  60772    Venezuela
#  60773    Venezuela
#  60786    Venezuela
#  60774    Venezuela
#             ...
#  61528      Vietnam
#  61529      Vietnam
#  61530      Vietnam
#  61531      Vietnam
#  61532      Vietnam
#  Name: airline_country, Length: 67, dtype: object,
#  61533    Vietnam
#  61534    Vietnam
#  61535    Vietnam
#  61536    Vietnam
#  61576    Vietnam
#            ...
#  61564    Vietnam
#  61406    Vietnam
#  61537    Vietnam
#  61408    Vietnam
#  61407    Vietnam
#  Name: airline_country, Length: 67, dtype: object,
#  61484    Vietnam
#  61483    Vietnam
#  61482    Vietnam
#  61481    Vietnam
#  61480    Vietnam
#            ...
#  61423    Vietnam
#  61422    Vietnam
#  61421    Vietnam
#  61420    Vietnam
#  61419    Vietnam
#  Name: airline_country, Length: 67, dtype: object,
#  61418    Vietnam
#  61417    Vietnam
#  61428    Vietnam
#  61416    Vietnam
#  61414    Vietnam
#            ...
#  33668      Yemen
#  33669      Yemen
#  33670      Yemen
#  33671      Yemen
#  33672      Yemen
#  Name: airline_country, Length: 67, dtype: object,
#  33650    Yemen
#  33673    Yemen
#  33674    Yemen
#  33663    Yemen
#  33649    Yemen
#           ...
#  33697    Yemen
#  33687    Yemen
#  33688    Yemen
#  33685    Yemen
#  33686    Yemen
#  Name: airline_country, Length: 67, dtype: object,
#  33679    Yemen
#  33680    Yemen
#  33681    Yemen
#  33677    Yemen
#  33696    Yemen
#           ...
#  64945       \N
#  64941       \N
#  64946       \N
#  64944       \N
#  64942       \N
#  Name: airline_country, Length: 67, dtype: object,
#  64943    \N
#  64947    \N
#  64939    \N
#  64929    \N
#  64937    \N
#           ..
#  64968    \N
#  64969    \N
#  64970    \N
#  64971    \N
#  64972    \N
#  Name: airline_country, Length: 67, dtype: object,
#  64973    \N
#  64974    \N
#  64975    \N
#  64966    \N
#  64917    \N
#           ..
#  45235    \N
#  45236    \N
#  45237    \N
#  45238    \N
#  45260    \N
#  Name: airline_country, Length: 67, dtype: object,
#  45261    \N
#  45262    \N
#  45263    \N
#  45264    \N
#  45265    \N
#           ..
#  45317    \N
#  45318    \N
#  45319    \N
#  45320    \N
#  45330    \N
#  Name: airline_country, Length: 67, dtype: object,
#  45321    \N
#  45323    \N
#  45324    \N
#  45325    \N
#  45326    \N
#           ..
#  45289    \N
#  31122    \N
#  31123    \N
#  31124    \N
#  2959     \N
#  Name: airline_country, Length: 67, dtype: object,
#  2960    \N
#  2961    \N
#  2962    \N
#  2963    \N
#  2964    \N
#          ..
#  2356    \N
#  2106    \N
#  2105    \N
#  2104    \N
#  2103    \N
#  Name: airline_country, Length: 67, dtype: object,
#  2102    \N
#  2101    \N
#  2107    \N
#  2364    \N
#  2365    \N
#          ..
#  3731    \N
#  3730    \N
#  3729    \N
#  3728    \N
#  3727    \N
#  Name: airline_country, Length: 67, dtype: object,
#  3726     \N
#  3732     \N
#  3725     \N
#  3723     \N
#  3722     \N
#           ..
#  3709     \N
#  3708     \N
#  3707     \N
#  44085    \N
#  45280    \N
#  Name: airline_country, Length: 67, dtype: object]

# %% [markdown]
# The other thing I would like to do if I had the time would be to make it so the partition breaks don't fall in the middle of set of like keys.
